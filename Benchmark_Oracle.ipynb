# %%
import pandas as pd
# %matplotlib notebook
# %matplotlib inline

# %% [markdown]
# <h1>Analise de Threads</h1>

# %% [markdown]
# <h3>1 Thread - Read Commmited</h3>

# %%
df_01 = pd.read_csv('read_commited/thread_1/thread_1.csv', sep=";")
df_01.groupby('tempo').size().plot(kind='line', figsize=(25,7))

# %% [markdown]
# <h3>1 Thread - Serializable</h3>

# %%
df_01 = pd.read_csv('serializable/thread_1/thread_1.csv', sep=";")
df_01.groupby('tempo').size().plot(kind='line', figsize=(25,7))

# %% [markdown]
# <h3>5 Threads - Read Commmited</h3>

# %%
df_05 = pd.read_csv('read_commited/thread_5/thread_5.csv', sep=";")
df_05.groupby('tempo').size().plot(kind='line', figsize=(25,7))

# %% [markdown]
# <h3>5 Threads - Serializable</h3>

# %%
df_01 = pd.read_csv('serializable/thread_5/thread_5.csv', sep=";")
df_01.groupby('tempo').size().plot(kind='line', figsize=(25,7))

# %% [markdown]
# <h3>10 Threads - Read Commmited</h3>

# %%
df_10 = pd.read_csv('read_commited/thread_10/thread_10.csv', sep=";")
df_10.groupby('tempo').size().plot(kind='line', figsize=(25,7))

# %% [markdown]
# <h3>10 Threads - Serializable</h3>

# %%
df_01 = pd.read_csv('serializable/thread_10/thread_10.csv', sep=";")
df_01.groupby('tempo').size().plot(kind='line', figsize=(25,7))

# %% [markdown]
# <h3>20 Threads - Read Commmited</h3>

# %%
df_20 = pd.read_csv('read_commited/thread_20/thread_20.csv', sep=";")
df_20.groupby('tempo').size().plot(kind='line', figsize=(25,7))

# %% [markdown]
# <h3>20 Threads - Serializable</h3>

# %%
df_01 = pd.read_csv('serializable/thread_20/thread_20.csv', sep=";")
df_01.groupby('tempo').size().plot(kind='line', figsize=(25,7))
